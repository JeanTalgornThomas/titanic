# %%
#pip install
pip3 install pyspark
# Out:
#   File "<ipython-input-8-305219ab05c6>", line 2
#     pip3 install pyspark
#                ^
# SyntaxError: invalid syntax

# %%
#Import
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-03d5bc767fb7> in <module>
#       1 #Import
# ----> 2 from pyspark.sql import SparkSession
#       3 from pyspark.conf import SparkConf
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
config = SparkConf()
spark = SparkSession.builder.master("local").appName("test").config(conf=config).getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-bef70c9be79a> in <module>
# ----> 1 from pyspark.sql import SparkSession
#       2 from pyspark.conf import SparkConf
#       3 config = SparkConf()
#       4 spark = SparkSession.builder.master("local").appName("test").config(conf=config).getOrCreate()
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
df = sc.read.option("header", "true").option("inferSchema", "true").csv("data\train.csv") 
df.printSchema()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\benpr\Documents\IPSSI\titanic\titanic\notebook.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/benpr/Documents/IPSSI/titanic/titanic/notebook.ipynb#ch0000000?line=0'>1</a> df = sc.read.option("header", "true").option("inferSchema", "true").csv("data\train.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/benpr/Documents/IPSSI/titanic/titanic/notebook.ipynb#ch0000000?line=1'>2</a> df.printSchema()
#
# AttributeError: 'Builder' object has no attribute 'read'
